# %%
import ccxt
print(ccxt.exchanges)
# Out:
# ['ace', 'alpaca', 'ascendex', 'bequant', 'bigone', 'binance', 'binancecoinm', 'binanceus', 'binanceusdm', 'bingx', 'bit2c', 'bitbank', 'bitbay', 'bitbns', 'bitcoincom', 'bitfinex', 'bitfinex2', 'bitflyer', 'bitget', 'bithumb', 'bitmart', 'bitmex', 'bitopro', 'bitpanda', 'bitrue', 'bitso', 'bitstamp', 'bitteam', 'bitvavo', 'bl3p', 'blockchaincom', 'blofin', 'btcalpha', 'btcbox', 'btcmarkets', 'btcturk', 'bybit', 'cex', 'coinbase', 'coinbaseadvanced', 'coinbaseexchange', 'coinbaseinternational', 'coincheck', 'coinex', 'coinlist', 'coinmate', 'coinmetro', 'coinone', 'coinsph', 'coinspot', 'cryptocom', 'currencycom', 'delta', 'deribit', 'digifinex', 'exmo', 'fmfwio', 'gate', 'gateio', 'gemini', 'hitbtc', 'hitbtc3', 'hollaex', 'htx', 'huobi', 'huobijp', 'hyperliquid', 'idex', 'independentreserve', 'indodax', 'kraken', 'krakenfutures', 'kucoin', 'kucoinfutures', 'kuna', 'latoken', 'lbank', 'luno', 'lykke', 'mercado', 'mexc', 'ndax', 'novadax', 'oceanex', 'okcoin', 'okx', 'onetrading', 'oxf
# ...

# %%
exchange=ccxt.coinbase({
     "apiKey": "organizations/361a33f7-d179-4bb2-9b5c-e004738924e0/apiKeys/e8e9f449-4dc8-4ad6-81d7-98b7b19ae5c6",
   "secret": "-----BEGIN EC PRIVATE KEY-----\nMHcCAQEEINGXdd+EMOsi8v9uAlWF8dyS6CLvUKoA6lG33ig0HTgToAoGCCqGSM49\nAwEHoUQDQgAECUSWna48h4qDjIhc7lOo4Hdb6UdX9BQFFKCNrxYyu1pLxjnY3CxS\nAFa02IQIVzt4a31+Ff1RPFbDz4HbtFnNCA==\n-----END EC PRIVATE KEY-----\n",
 "enableRateLimit": True
})

# %%
print(exchange.apiKey)
print(exchange.secret)
# Out:
# organizations/361a33f7-d179-4bb2-9b5c-e004738924e0/apiKeys/e8e9f449-4dc8-4ad6-81d7-98b7b19ae5c6
# -----BEGIN EC PRIVATE KEY-----
# MHcCAQEEINGXdd+EMOsi8v9uAlWF8dyS6CLvUKoA6lG33ig0HTgToAoGCCqGSM49
# AwEHoUQDQgAECUSWna48h4qDjIhc7lOo4Hdb6UdX9BQFFKCNrxYyu1pLxjnY3CxS
# AFa02IQIVzt4a31+Ff1RPFbDz4HbtFnNCA==
# -----END EC PRIVATE KEY-----

# %%
markets = exchange.load_markets()
ticker = exchange.fetch_ticker('BTC/USD')
print(ticker)
# Out:
# {'symbol': 'BTC/USD', 'timestamp': 1723592833956, 'datetime': '2024-08-13T23:47:13.956443Z', 'bid': 60446.56, 'ask': 60446.57, 'last': 60446.57, 'high': None, 'low': None, 'bidVolume': None, 'askVolume': None, 'vwap': None, 'open': None, 'close': 60446.57, 'previousClose': None, 'change': None, 'percentage': None, 'average': None, 'baseVolume': None, 'quoteVolume': None, 'info': {'trade_id': '680240880', 'product_id': 'BTC-USD', 'price': '60446.57', 'size': '0.00006568', 'time': '2024-08-13T23:47:13.956443Z', 'side': 'SELL', 'bid': '', 'ask': ''}}

# %%
balance = exchange.fetch_balance()
print(balance)
# Out:
# {'info': {'data': [{'id': 'dffd372b-10fc-5fd8-b1a4-9e8157635f7c', 'name': 'ETH2 Wallet', 'primary': True, 'type': 'wallet', 'balance': {'amount': '0.00000000', 'currency': 'ETH2'}, 'created_at': '2024-07-07T19:48:33Z', 'updated_at': '2024-07-07T19:48:33Z', 'resource': 'account', 'resource_path': '/v2/accounts/dffd372b-10fc-5fd8-b1a4-9e8157635f7c', 'currency': {'asset_id': '3bec5bf3-507a-51ba-8e41-dc953b1a5c4d', 'code': 'ETH2', 'color': '#8E76FF', 'exponent': '8', 'name': 'Ethereum 2', 'slug': 'ethereum-2', 'type': 'crypto', 'rewards': {'apy': '0.02240086', 'formatted_apy': '2.24%', 'label': '2.24% APY'}}, 'allow_deposits': False, 'allow_withdrawals': False}, {'id': '60757be5-24a9-5376-a3cc-fdfc1503610a', 'name': 'Cash (USD)', 'primary': False, 'type': 'fiat', 'balance': {'amount': '0.00', 'currency': 'USD'}, 'created_at': '2024-07-07T19:47:31Z', 'updated_at': '2024-07-07T19:47:31Z', 'resource': 'account', 'resource_path': '/v2/accounts/60757be5-24a9-5376-a3cc-fdfc1503610a', 'currency
# ...

# %%
data=exchange.fetch_ohlcv("BTC-USD","15m",limit=200)
print(data)
# Out:
# [[1723413600000, 59014.71, 59351.64, 58613.32, 58625.97, 256.2470959], [1723414500000, 58629.99, 58835.33, 58535.5, 58687.92, 119.22030466], [1723415400000, 58687.92, 58977.94, 58534.68, 58880.83, 101.44317433], [1723416300000, 58880.82, 59169.96, 58865.03, 59000.39, 66.98376984], [1723417200000, 58995.67, 58995.67, 58705.03, 58760.7, 55.89364529], [1723418100000, 58761.98, 59007.79, 58725.73, 58959.42, 51.12363825], [1723419000000, 58959.43, 59029.83, 58814.32, 58825.23, 76.09163149], [1723419900000, 58825.22, 58881.76, 58686.42, 58722.49, 59.3005687], [1723420800000, 58717.44, 58894.28, 58639.13, 58887.36, 79.89234511], [1723421700000, 58881.63, 59085.98, 58636.9, 58648.08, 67.30074575], [1723422600000, 58650.56, 58654.52, 58103.61, 58346.36, 238.33126365], [1723423500000, 58346.36, 58715.82, 58337.04, 58455.94, 149.05811155], [1723424400000, 58451.65, 58665.66, 58268.82, 58615.27, 91.70493348], [1723425300000, 58602.88, 58795.07, 58500.0, 58508.94, 76.26015411], [1723426200000, 58
# ...
