# %%
import ccxt
import os
from dotenv import load_dotenv
print(ccxt.exchanges)
# Out:
# ['ace', 'alpaca', 'ascendex', 'bequant', 'bigone', 'binance', 'binancecoinm', 'binanceus', 'binanceusdm', 'bingx', 'bit2c', 'bitbank', 'bitbns', 'bitcoincom', 'bitfinex', 'bitfinex2', 'bitflyer', 'bitget', 'bithumb', 'bitmart', 'bitmex', 'bitopro', 'bitpanda', 'bitrue', 'bitso', 'bitstamp', 'bitteam', 'bitvavo', 'bl3p', 'blockchaincom', 'blofin', 'btcalpha', 'btcbox', 'btcmarkets', 'btcturk', 'bybit', 'cex', 'coinbase', 'coinbaseadvanced', 'coinbaseexchange', 'coinbaseinternational', 'coincheck', 'coinex', 'coinlist', 'coinmate', 'coinmetro', 'coinone', 'coinsph', 'coinspot', 'cryptocom', 'currencycom', 'delta', 'deribit', 'digifinex', 'exmo', 'fmfwio', 'gate', 'gateio', 'gemini', 'hashkey', 'hitbtc', 'hollaex', 'htx', 'huobi', 'huobijp', 'hyperliquid', 'idex', 'independentreserve', 'indodax', 'kraken', 'krakenfutures', 'kucoin', 'kucoinfutures', 'kuna', 'latoken', 'lbank', 'luno', 'lykke', 'mercado', 'mexc', 'ndax', 'novadax', 'oceanex', 'okcoin', 'okx', 'onetrading', 'oxfun', 'p2b', 'paradex', 'paymium', 'phemex', 'poloniex', 'poloniexfutures', 'probit', 'timex', 'tokocrypto', 'tradeogre', 'upbit', 'vertex', 'wavesexchange', 'wazirx', 'whitebit', 'woo', 'woofipro', 'xt', 'yobit', 'zaif', 'zonda']

# %%
load_dotenv()
# Out:
# True

# %%
secret_key = os.getenv("COINBASE_SECRET").replace("\\n", "\n")

# %%
exchange = ccxt.coinbase({
    "apiKey": os.getenv("COINBASE_API_KEY"),
    "secret": secret_key,
    "enableRateLimit": True
})

# %%
print("Credentials loaded securely from .env file.")
# Out:
# Credentials loaded securely from .env file.

# %%
markets = exchange.load_markets()
ticker = exchange.fetch_ticker('BTC/USD')
print(ticker)
# Out:
# {'symbol': 'BTC/USD', 'timestamp': 1758143872189, 'datetime': '2025-09-17T21:17:52.189898Z', 'bid': 115754.39, 'ask': 115754.4, 'last': 115754.4, 'high': None, 'low': None, 'bidVolume': None, 'askVolume': None, 'vwap': None, 'open': None, 'close': 115754.4, 'previousClose': None, 'change': None, 'percentage': None, 'average': None, 'baseVolume': None, 'quoteVolume': None, 'info': {'trade_id': '875138544', 'product_id': 'BTC-USD', 'price': '115754.4', 'size': '0.00020981', 'time': '2025-09-17T21:17:52.189898Z', 'side': 'SELL', 'bid': '', 'ask': '', 'exchange': 'coinbase'}}

# %%
balance = exchange.fetch_balance()
print(balance)
# Out:
# {'info': {'data': [{'id': 'dffd372b-10fc-5fd8-b1a4-9e8157635f7c', 'name': 'ETH2 Wallet', 'primary': True, 'type': 'wallet', 'balance': {'amount': '0.00000000', 'currency': 'ETH2'}, 'created_at': '2024-07-07T19:48:33Z', 'updated_at': '2024-07-07T19:48:33Z', 'resource': 'account', 'resource_path': '/v2/accounts/dffd372b-10fc-5fd8-b1a4-9e8157635f7c', 'currency': {'asset_id': '3bec5bf3-507a-51ba-8e41-dc953b1a5c4d', 'code': 'ETH2', 'color': '#8E76FF', 'exponent': '8', 'name': 'Ethereum 2', 'slug': 'ethereum-2', 'type': 'crypto', 'rewards': {'apy': '0.01861176', 'formatted_apy': '1.86%', 'label': '1.86% APY'}}, 'allow_deposits': False, 'allow_withdrawals': False, 'portfolio_id': 'f7e409df-a6e6-5d04-8863-ff4b4a700414'}, {'id': '60757be5-24a9-5376-a3cc-fdfc1503610a', 'name': 'Cash (USD)', 'primary': False, 'type': 'fiat', 'balance': {'amount': '0.00', 'currency': 'USD'}, 'created_at': '2024-07-07T19:47:31Z', 'updated_at': '2024-07-07T19:47:31Z', 'resource': 'account', 'resource_path': '/v2/accounts/60757be5-24a9-5376-a3cc-fdfc1503610a', 'currency': {'asset_id': '', 'code': 'USD', 'color': '#0066cf', 'exponent': '2', 'name': 'United States Dollar', 'slug': '', 'type': 'fiat', 'rewards': None}, 'allow_deposits': True, 'allow_withdrawals': True, 'portfolio_id': 'f7e409df-a6e6-5d04-8863-ff4b4a700414'}, {'id': '905c1450-4c8f-50a2-ae82-d5086b2b307a', 'name': 'BTC Wallet', 'primary': True, 'type': 'wallet', 'balance': {'amount': '0.00000000', 'currency': 'BTC'}, 'created_at': '2024-07-07T19:45:12Z', 'updated_at': '2024-07-07T19:45:17Z', 'resource': 'account', 'resource_path': '/v2/accounts/905c1450-4c8f-50a2-ae82-d5086b2b307a', 'currency': {'asset_id': '5b71fc48-3dd3-540c-809b-f8c94d0e68b5', 'code': 'BTC', 'color': '#F7931A', 'exponent': '8', 'name': 'Bitcoin', 'slug': 'bitcoin', 'type': 'crypto', 'rewards': None}, 'allow_deposits': True, 'allow_withdrawals': True, 'portfolio_id': 'f7e409df-a6e6-5d04-8863-ff4b4a700414'}], 'pagination': {'ending_before': None, 'limit': '100', 'next_starting_after': None, 'next_uri': None, 'order': 'desc', 'previous_ending_before': None, 'previous_uri': None, 'starting_after': None}}, 'ETH2': {'free': 0.0, 'used': 0.0, 'total': 0.0}, 'USD': {'free': 0.0, 'used': 0.0, 'total': 0.0}, 'BTC': {'free': 0.0, 'used': 0.0, 'total': 0.0}, 'free': {'ETH2': 0.0, 'USD': 0.0, 'BTC': 0.0}, 'used': {'ETH2': 0.0, 'USD': 0.0, 'BTC': 0.0}, 'total': {'ETH2': 0.0, 'USD': 0.0, 'BTC': 0.0}}

# %%
data=exchange.fetch_ohlcv("BTC-USD","15m",limit=200)
print(data)
# Out:
# [[1757964600000, 115112.85, 115594.82, 114984.99, 115452.79, 216.80190982], [1757965500000, 115452.96, 115504.48, 115265.8, 115327.01, 119.52776722], [1757966400000, 115326.01, 115537.42, 115279.55, 115488.31, 44.3241399], [1757967300000, 115488.32, 115522.0, 115300.0, 115304.8, 68.65795708], [1757968200000, 115304.81, 115378.89, 115229.8, 115287.09, 43.9479918], [1757969100000, 115287.08, 115411.99, 115219.56, 115411.99, 51.58241524], [1757970000000, 115411.99, 115437.08, 115304.8, 115335.14, 58.54349784], [1757970900000, 115335.13, 115506.59, 115322.0, 115469.77, 70.28643159], [1757971800000, 115469.77, 115546.47, 115412.08, 115543.66, 19.40151785], [1757972700000, 115543.08, 115561.51, 115512.81, 115536.92, 15.70084076], [1757973600000, 115536.94, 115644.2, 115280.19, 115438.18, 43.33083669], [1757974500000, 115438.18, 115505.27, 115